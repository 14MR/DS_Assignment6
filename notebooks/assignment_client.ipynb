# %%
# !apt-get install build-essential swig
# !pip install -r ../requirements.txt
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...
#   Using cached pandas_profiling-3.1.0-py2.py3-none-any.whl (261 kB)
# ...
#   Using cached missingno-0.5.1-py3-none-any.whl (8.7 kB)
# ...
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...

# %%
# !python3 ../src/models/model_development.py
# Out:
# 07-04-2022 11:26:27 : INFO : model_development : <module> : 69 : (Process Details : (59774, MainProcess), Thread Details : (4644728256, MainThread))
# Log : train test split with test_size=0.2 and random state=0
# 07-04-2022 11:26:27 : DEBUG : logging_ : debug : 80 : (Process Details : (59774, MainProcess), Thread Details : (4644728256, MainThread))
# Log : _make_internals_directory: [Errno 17] File exists: '/var/folders/pq/76ml5mv52677z40wqfbz20g00000gn/T/auto-sklearn_tmp_6228ec84-b6b9-11ec-a97e-faffc2008f09/.auto-sklearn'
# 07-04-2022 11:26:27 : DEBUG : logging_ : debug : 80 : (Process Details : (59774, MainProcess), Thread Details : (4644728256, MainThread))
# Log : _make_internals_directory: [Errno 17] File exists: '/var/folders/pq/76ml5mv52677z40wqfbz20g00000gn/T/auto-sklearn_tmp_6228ec84-b6b9-11ec-a97e-faffc2008f09/.auto-sklearn/runs'
# 07-04-2022 11:26:27 : DEBUG : logging_ : debug : 109 : (Process Details : (59774, MainProcess), Thread Details : (4644728256, MainThread))
# ...

# %%
# !cd .. && python3 src/models/model_serving.py &  # or run manually
import requests
import json

features = [-117.05, 32.58, 22.0, 201.0, 399.0, 1551.0, 371.0, 4.1518]
req = requests.post('http://127.0.0.1:5000',
                    headers = {'Content-Type': 'application/json'},
                    data = json.dumps({'features': features})
                    )
print(req.json()["prediction"])
# Out:
# 100568.36938476562
